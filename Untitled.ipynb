# %%
from sqlalchemy import create_engine
import pandas as pd
import matplotlib.pyplot as plt

engine = create_engine("mysql+pymysql://root:october2006@localhost/employee_db")

# %%
# Load all employees
df = pd.read_sql("SELECT * FROM employees", engine)
df.head(20)
# Out:
#     emp_id             name  department_id   salary  gender   hire_date
# 0        1      Amit Sharma              1  55000.0    male  2018-03-15
# 1        2      Priya Verma              2  62000.0  female  2019-07-10
# 2        3      Rohit Singh              1  48000.0    male  2020-01-20
# 3        4       Neha Gupta              3  75000.0  female  2017-11-05
# 4        5      Arjun Mehta              2  51000.0    male  2021-06-12
# 5        6     Sneha Kapoor              4  68000.0  female  2016-09-25
# 6        7      Vikas Yadav              1  45000.0    male  2022-02-14
# 7        8    Anjali Mishra              3  72000.0  female  2018-12-01
# 8        9      Karan Patel              2  53000.0    male  2019-05-18
# 9       10      Meera Joshi              4  70000.0  female  2020-08-22
# 10      11     Suresh Raina              1  46000.0    male  2021-03-30
# 11      12     Divya Saxena              3  76000.0  female  2017-04-11
# 12      13     Manish Kumar              2  60000.0    male  2019-09-09
# 13      14       Pooja Nair              4  69000.0  female  2016-12-19
# 14      15    Rahul Chauhan              1  52000.0    male  2020-10-07
# 15      16   Shweta Agarwal              3  74000.0  female  2018-05-23
# 16      17  Deepak Malhotra              2  58000.0    male  2019-11-15
# 17      18     Ritika Desai              4  71000.0  female  2021-01-28
# 18      19    Sanjay Pandey              1  49000.0    male  2022-07-04
# 19      20      Kavita Iyer              3  77000.0  female  2017-02-17

# %%
# Employees hired after 2018
df_hired = pd.read_sql("SELECT * FROM employees WHERE hire_date > '2018-01-01'", engine)
df_hired
# Out:
#     emp_id             name  department_id   salary  gender   hire_date
# 0        1      Amit Sharma              1  55000.0    male  2018-03-15
# 1        2      Priya Verma              2  62000.0  female  2019-07-10
# 2        3      Rohit Singh              1  48000.0    male  2020-01-20
# 3        5      Arjun Mehta              2  51000.0    male  2021-06-12
# 4        7      Vikas Yadav              1  45000.0    male  2022-02-14
# 5        8    Anjali Mishra              3  72000.0  female  2018-12-01
# 6        9      Karan Patel              2  53000.0    male  2019-05-18
# 7       10      Meera Joshi              4  70000.0  female  2020-08-22
# 8       11     Suresh Raina              1  46000.0    male  2021-03-30
# 9       13     Manish Kumar              2  60000.0    male  2019-09-09
# 10      15    Rahul Chauhan              1  52000.0    male  2020-10-07
# 11      16   Shweta Agarwal              3  74000.0  female  2018-05-23
# 12      17  Deepak Malhotra              2  58000.0    male  2019-11-15
# 13      18     Ritika Desai              4  71000.0  female  2021-01-28
# 14      19    Sanjay Pandey              1  49000.0    male  2022-07-04

# %%
# Average salary by department
avg_salary = pd.read_sql("""
SELECT department_id, AVG(salary) AS avg_salary
FROM employees
GROUP BY department_id
""", engine)
avg_salary
# Out:
#    department_id    avg_salary
# 0              1  49166.666667
# 1              2  56800.000000
# 2              3  74800.000000
# 3              4  69500.000000

# %%
# Salary distribution histogram
df['salary'].hist(bins=10)
plt.title("Salary Distribution")
plt.xlabel("Salary")
plt.ylabel("Count")
plt.show()
